# %% [markdown]
# Unifying the dataset from Trade_inn

# %%
import pandas as pd
import re

# %%
basketball_items = pd.read_csv('basketball.csv')
basketball_items
# Out:
#                                                  image  \
# 0    https://www.tradeinn.com/h/13835/138357411/spa...
# 1    https://www.tradeinn.com/h/13835/138357390/spa...
# 2    https://www.tradeinn.com/h/13837/138377737/nik...
# 3    https://www.tradeinn.com/h/13893/138936721/skl...
# 4    https://www.tradeinn.com/h/13837/138377738/nik...
# ..                                                 ...
# 900  https://www.tradeinn.com/h/13780/137808250/hum...
# 901  https://www.tradeinn.com/h/13841/138410088/err...
# 902  https://www.tradeinn.com/h/13841/138413304/err...
# 903  https://www.tradeinn.com/h/13841/138412198/err...
# 904  https://www.tradeinn.com/h/13841/138412352/err...
#
#                                            description   category collection  \
# 0                   spalding slam dunk basketball ball  equipment      balls
# 1                    spalding max grip basketball ball  equipment      balls
# ...

# %%
basketball_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
basketball_items.rename(columns={'image': 'image_src'}, inplace=True)
basketball_items.rename(columns={'description': 'title'}, inplace=True)

# %%
basketball_items['collection'].value_counts()
# Out:
# adult    593
# balls    290
# kid       22
# Name: collection, dtype: int64

# %%
basketball_items['category'].value_counts()
# Out:
# clothing     368
# equipment    290
# shoes        247
# Name: category, dtype: int64

# %%
basketball_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           905 non-null    object
#  1   title               905 non-null    object
#  2   category            905 non-null    object
#  3   collection          905 non-null    object
#  4   suggested_price(€)  905 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 35.5+ KB

# %%
basketball_items.to_csv('basketball_items.csv')

# %%
bike_items = pd.read_csv('bike.csv')
bike_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13911/139114161/toi...
# 1     https://www.tradeinn.com/h/13911/139114057/toi...
# 2     https://www.tradeinn.com/h/13911/139114134/toi...
# 3     https://www.tradeinn.com/h/13978/139784630/toi...
# 4     https://www.tradeinn.com/h/13911/139114162/toi...
# ...                                                 ...
# 1969  https://www.tradeinn.com/h/13829/138291556/cas...
# 1970  https://www.tradeinn.com/h/13844/138441927/cas...
# 1971  https://www.tradeinn.com/h/13753/137537618/cas...
# 1972  https://www.tradeinn.com/h/13829/138291531/cas...
# 1973  https://www.tradeinn.com/h/13638/136384115/cas...
#
#                                     description  category collection   price
# 0        toimsa bikes spiderman huffy 14´´ bike      bike        kid  126.99
# 1               toimsa bikes blue ice 16´´ bike      bike        kid  109.99
# ...

# %%
bike_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
bike_items.rename(columns={'image': 'image_src'}, inplace=True)
bike_items.rename(columns={'description': 'title'}, inplace=True)

# %%
bike_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           1974 non-null   object
#  1   title               1974 non-null   object
#  2   category            1974 non-null   object
#  3   collection          1974 non-null   object
#  4   suggested_price(€)  1974 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 77.2+ KB

# %%
bike_items.to_csv('bike_items.csv')

# %%
football_items = pd.read_csv('football.csv')
football_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13992/139925435/adi...
# 1     https://www.tradeinn.com/h/13992/139925460/adi...
# 2     https://www.tradeinn.com/h/13992/139925439/adi...
# 3     https://www.tradeinn.com/h/13992/139925440/adi...
# 4     https://www.tradeinn.com/h/13992/139927702/adi...
# ...                                                 ...
# 2418  https://www.tradeinn.com/h/13944/139444159/hua...
# 2419  https://www.tradeinn.com/h/13944/139444161/hua...
# 2420  https://www.tradeinn.com/h/13944/139444160/hua...
# 2421  https://www.tradeinn.com/h/13936/139368805/hua...
# 2422  https://www.tradeinn.com/h/13936/139368820/hua...
#
#                                             description   category collection  \
# 0     adidas real madrid 23/24 short sleeve t-shirt ...  equipment      adult
# 1     adidas real madrid 23/24 woman short sleeve t-...  equipment      adult
# ...

# %%
football_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
football_items.rename(columns={'image': 'image_src'}, inplace=True)
football_items.rename(columns={'description': 'title'}, inplace=True)

# %%
football_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2423 entries, 0 to 2422
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           2423 non-null   object
#  1   title               2423 non-null   object
#  2   category            2423 non-null   object
#  3   collection          2423 non-null   object
#  4   suggested_price(€)  2423 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 94.8+ KB

# %%
football_items.to_csv('football_items.csv')

# %%
kids_items = pd.read_csv('kids.csv')
kids_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13637/136375417/van...
# 1     https://www.tradeinn.com/h/13896/138960920/adi...
# 2     https://www.tradeinn.com/h/13842/138426741/adi...
# 3     https://www.tradeinn.com/h/13842/138426738/adi...
# 4     https://www.tradeinn.com/h/13842/138426737/adi...
# ...                                                 ...
# 4815  https://www.tradeinn.com/h/13999/139997291/for...
# 4816  https://www.tradeinn.com/h/13999/139997283/for...
# 4817  https://www.tradeinn.com/h/14033/140336177/leo...
# 4818  https://www.tradeinn.com/h/13999/139997287/for...
# 4819  https://www.tradeinn.com/h/13955/139550566/tec...
#
#                                            description   category collection  \
# 0                              vans old skool trainers  equipment        kid
# 1                    adidas grand court 2.0 shoes kids  equipment        kid
# ...

# %%
kids_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
kids_items.rename(columns={'image': 'image_src'}, inplace=True)
kids_items.rename(columns={'description': 'title'}, inplace=True)

# %%
kids_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4820 entries, 0 to 4819
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           4820 non-null   object
#  1   title               4820 non-null   object
#  2   category            4820 non-null   object
#  3   collection          4820 non-null   object
#  4   suggested_price(€)  4820 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 188.4+ KB

# %%
kids_items.to_csv('kids_items.csv')

# %%
padel_items = pd.read_csv('padel.csv')
padel_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/14045/140459970/sta...
# 1     https://www.tradeinn.com/h/13795/137951941/hea...
# 2     https://www.tradeinn.com/h/13849/138491272/hea...
# 3     https://www.tradeinn.com/h/13969/139698507/4on...
# 4     https://www.tradeinn.com/h/13926/139261723/hea...
# ...                                                 ...
# 1984  https://www.tradeinn.com/h/13884/138847565/k-s...
# 1985  https://www.tradeinn.com/h/13853/138534143/mun...
# 1986  https://www.tradeinn.com/h/13940/139401282/mun...
# 1987  https://www.tradeinn.com/h/13940/139401285/mun...
# 1988  https://www.tradeinn.com/h/13862/138625897/sal...
#
#                                   description   category collection   price
# 0                star vie triton padel racket  equipment      padel  232.49
# 1                     head flash padel racket  equipment      padel   99.00
# ...

# %%
padel_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
padel_items.rename(columns={'image': 'image_src'}, inplace=True)
padel_items.rename(columns={'description': 'title'}, inplace=True)

# %%
padel_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           1989 non-null   object
#  1   title               1989 non-null   object
#  2   category            1989 non-null   object
#  3   collection          1989 non-null   object
#  4   suggested_price(€)  1989 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 77.8+ KB

# %%
padel_items.to_csv('pedo_items.csv')

# %%
running_items = pd.read_csv('running.csv')
running_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13855/138552287/nik...
# 1     https://www.tradeinn.com/h/14003/140033883/sal...
# 2     https://www.tradeinn.com/h/13993/139934827/adi...
# 3     https://www.tradeinn.com/h/13944/139448735/sal...
# 4     https://www.tradeinn.com/h/13883/138838893/nik...
# ...                                                 ...
# 7448  https://www.tradeinn.com/h/13777/137776902/sam...
# 7449  https://www.tradeinn.com/h/13776/137769950/sam...
# 7450  https://www.tradeinn.com/h/13974/139740777/for...
# 7451  https://www.tradeinn.com/h/14038/140383149/hua...
# 7452  https://www.tradeinn.com/h/13777/137776904/sam...
#
#                                            description   category collection  \
# 0                   nike revolution 6 nn running shoes      shoes        man
# 1     salomon xa pro 3d v9 goretex trail running shoes      shoes        man
# ...

# %%
running_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
running_items.rename(columns={'image': 'image_src'}, inplace=True)
running_items.rename(columns={'description': 'title'}, inplace=True)

# %%
running_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7453 entries, 0 to 7452
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           7453 non-null   object
#  1   title               7453 non-null   object
#  2   category            7453 non-null   object
#  3   collection          7453 non-null   object
#  4   suggested_price(€)  7453 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 291.3+ KB

# %%
running_items.to_csv('running_items.csv')

# %%
surf_items =pd.read_csv('surf.csv')
surf_items
# Out:
#                                                  image  \
# 0    https://www.tradeinn.com/h/13876/138767487/cbc...
# 1    https://www.tradeinn.com/h/13805/138055082/moa...
# 2    https://www.tradeinn.com/h/13876/138767539/rip...
# 3    https://www.tradeinn.com/h/13876/138767540/rip...
# 4    https://www.tradeinn.com/h/13805/138055086/moa...
# ..                                                 ...
# 595  https://www.tradeinn.com/h/13974/139747382/dew...
# 596  https://www.tradeinn.com/h/13974/139747386/dew...
# 597  https://www.tradeinn.com/h/13974/139747388/dew...
# 598  https://www.tradeinn.com/h/13974/139747389/dew...
# 599  https://www.tradeinn.com/h/13812/138125119/moa...
#
#                              description   category   price
# 0              cbc wood 39.5´´ skimboard  equipment   45.99
# 1              moana mini 30´´ bodyboard  equipment   20.99
# 2          rip bois 7 ply 37´´ skimboard  equipment   28.99
# 3            rip bois ply 39´´ skimboard  equipment   30.99
# ...

# %%
surf_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
surf_items.rename(columns={'image': 'image_src'}, inplace=True)
surf_items.rename(columns={'description': 'title'}, inplace=True)

# %%
surf_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           600 non-null    object
#  1   title               600 non-null    object
#  2   category            600 non-null    object
#  3   suggested_price(€)  600 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 18.9+ KB

# %%
surf_items.to_csv('surf_items.csv')

# %%
swim_items= pd.read_csv('swim.csv')
swim_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13756/137568221/sof...
# 1     https://www.tradeinn.com/h/13733/137332340/are...
# 2     https://www.tradeinn.com/h/13959/139594445/spe...
# 3     https://www.tradeinn.com/h/13792/137927462/spe...
# 4     https://www.tradeinn.com/h/13689/136892744/are...
# ...                                                 ...
# 5309  https://www.tradeinn.com/h/13615/136157754/swi...
# 5310  https://www.tradeinn.com/h/13615/136157758/swi...
# 5311  https://www.tradeinn.com/h/13810/138105476/rog...
# 5312  https://www.tradeinn.com/h/13615/136157756/swi...
# 5313  https://www.tradeinn.com/h/13615/136157752/swi...
#
#                                             description   category  \
# 0                         softee polyester swimming cap  equipment
# 1       arena cobra ultra swipe mirror swimming goggles  equipment
# 2     speedo fastskin pure focus mirror swimming gog...  equipment
# ...

# %%
swim_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
swim_items.rename(columns={'image': 'image_src'}, inplace=True)
swim_items.rename(columns={'description': 'title'}, inplace=True)

# %%
swim_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5314 entries, 0 to 5313
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           5314 non-null   object
#  1   title               5314 non-null   object
#  2   category            5314 non-null   object
#  3   colection           5314 non-null   object
#  4   suggested_price(€)  5314 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 207.7+ KB

# %%
swim_items.to_csv('swim_items.csv')

# %%
tennis_items = pd.read_csv('tennis.csv')
tennis_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13914/139146578/wil...
# 1     https://www.tradeinn.com/h/13776/137762395/bab...
# 2     https://www.tradeinn.com/h/13776/137762363/bab...
# 3     https://www.tradeinn.com/h/13776/137762394/bab...
# 4     https://www.tradeinn.com/h/13776/137762367/bab...
# ...                                                 ...
# 4804  https://www.tradeinn.com/h/13976/139765435/dia...
# 4805  https://www.tradeinn.com/h/13935/139355657/lot...
# 4806  https://www.tradeinn.com/h/13935/139355681/lot...
# 4807  https://www.tradeinn.com/h/13869/138693163/kel...
# 4808  https://www.tradeinn.com/h/13869/138693162/kel...
#
#                                          description   category collection  \
# 0                 wilson blade 101l v8 tennis racket  equipment     tennis
# 1                babolat pure drive 26 tennis racket  equipment     tennis
# ...

# %%
tennis_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
tennis_items.rename(columns={'image': 'image_src'}, inplace=True)
tennis_items.rename(columns={'description': 'title'}, inplace=True)

# %%
tennis_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           4809 non-null   object
#  1   title               4809 non-null   object
#  2   category            4809 non-null   object
#  3   collection          4809 non-null   object
#  4   suggested_price(€)  4809 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 188.0+ KB

# %%
tennis_items.to_csv('tennis_items.csv')

# %%
training_items = pd.read_csv('training.csv')
training_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/13771/137712412/adi...
# 1     https://www.tradeinn.com/h/13794/137942946/adi...
# 2     https://www.tradeinn.com/h/13785/137858413/adi...
# 3     https://www.tradeinn.com/h/13771/137712413/adi...
# 4     https://www.tradeinn.com/h/13733/137330940/miz...
# ...                                                 ...
# 4665  https://www.tradeinn.com/h/14047/140477103/inn...
# 4666  https://www.tradeinn.com/h/14047/140477214/inn...
# 4667  https://www.tradeinn.com/h/13943/139431939/oko...
# 4668  https://www.tradeinn.com/h/13943/139431944/oko...
# 4669  https://www.tradeinn.com/h/14047/140477201/inn...
#
#                                   description   category collection  price
# 0          adidas originals 3 units face mask   clothing        man   8.99
# 1          adidas 4 stripes 3 units face mask   clothing        man  11.49
# ...

# %%
training_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
training_items.rename(columns={'image': 'image_src'}, inplace=True)
training_items.rename(columns={'description': 'title'}, inplace=True)

# %%
training_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4670 entries, 0 to 4669
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           4670 non-null   object
#  1   title               4670 non-null   object
#  2   category            4670 non-null   object
#  3   collection          4670 non-null   object
#  4   suggested_price(€)  4670 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 182.6+ KB

# %%
training_items.to_csv('training_items.csv')

# %%
treking_items = pd.read_csv('treking.csv')
treking_items
# Out:
#                                                   image  \
# 0     https://www.tradeinn.com/h/14037/140370833/app...
# 1     https://www.tradeinn.com/h/13945/139458006/sam...
# 2     https://www.tradeinn.com/h/14037/140371252/app...
# 3     https://www.tradeinn.com/h/13721/137216707/gar...
# 4     https://www.tradeinn.com/h/13715/137159617/gar...
# ...                                                 ...
# 5983  https://www.tradeinn.com/h/13896/138961563/adi...
# 5984  https://www.tradeinn.com/h/13842/138429414/adi...
# 5985  https://www.tradeinn.com/h/13791/137918722/sal...
# 5986  https://www.tradeinn.com/h/13944/139448852/sal...
# 5987  https://www.tradeinn.com/h/13944/139448748/sal...
#
#                                             description   category collection  \
# 0     apple watch ultra 2 gps+cellular loop alpine 4...  equipment        gps
# 1        samsung galaxy watch 5 pro 4g 45 mm smartwatch  equipment      watch
# ...

# %%
treking_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
treking_items.rename(columns={'image': 'image_src'}, inplace=True)
treking_items.rename(columns={'description': 'title'}, inplace=True)

# %%
treking_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5988 entries, 0 to 5987
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_src           5988 non-null   object
#  1   title               5988 non-null   object
#  2   category            5988 non-null   object
#  3   collection          5988 non-null   object
#  4   suggested_price(€)  5988 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 234.0+ KB

# %%
treking_items.to_csv('treking_items.csv')

# %%
book_items = pd.read_csv('all_bestsellers.csv')
book_items
# Out:
#            Category                                              Image  \
# 0    Art and Design  https://blackwells.co.uk//jacket/200x200/97818...
# 1    Art and Design  https://blackwells.co.uk//jacket/200x200/97817...
# 2    Art and Design  https://blackwells.co.uk//jacket/200x200/97813...
# 3    Art and Design  https://blackwells.co.uk//jacket/200x200/97807...
# 4    Art and Design  https://blackwells.co.uk//jacket/200x200/97810...
# ..              ...                                                ...
# 535          Travel  https://blackwells.co.uk//jacket/200x200/97800...
# 536          Travel  https://blackwells.co.uk//jacket/200x200/97816...
# 537          Travel  https://blackwells.co.uk//jacket/200x200/97806...
# 538          Travel  https://blackwells.co.uk//jacket/200x200/97819...
# 539          Travel  https://blackwells.co.uk//jacket/200x200/97817...
#
#                                   Title                   Author  Price
# ...

# %%
book_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  540 non-null    object
#  1   Image     540 non-null    object
#  2   Title     540 non-null    object
#  3   Author    538 non-null    object
#  4   Price     540 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 21.2+ KB

# %%
book_items.rename(columns={'price': 'suggested_price(€)'}, inplace=True)
book_items.rename(columns={'image': 'image_src'}, inplace=True)
book_items.rename(columns={'description': 'title'}, inplace=True)
book_items.rename(columns={'Category': 'category'}, inplace=True)
book_items.rename(columns={'Author': 'author'}, inplace=True)

# %%
book_items.to_csv('book_items.csv')
